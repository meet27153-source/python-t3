# %%
# Out:
# '[image.png]' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f=open("python.txt")
print(f.read())
f.read()
f.seek(0)
print(f.read())
f.close()
# Out:
# Python 1234
# Python 1234
# UsageError: Line magic function `%%writefile` not found.

# %%
# %%writefile p.txt
# wdwdwe
# Out:
# Writing p.txt

# %%
with open('python.txt','r') as f:
    print(f.read())
print(f.closed)
# Out:
# Python 1234
# True

# %%
f=open('python.txt')
print(f.read())
print(f.closed)
f.close()
print(f.closed)
# Out:
# Python 1234
# False
# True

# %%
with open('python.txt') as f:
    print(f.write("N"))
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-20-40a230fd484a> in <module>
#       1 with open('python.txt') as f:
# ----> 2     print(f.write("N"))
#
# UnsupportedOperation: not writable

# %%
with open('python.txt','r+') as f:
    
    print(f.tell())
    print(f.write("hjjkn"))
    print(f.tell())
# Out:
# 0
# 5
# 5

# %%
with open('hola.txt','w+') as f:
    print(f.write("test 1 \n"))
    print(f.write("test 2 \n"))
    print(f.write("test 3 \n"))
    print(f.seek(0))
    print(f.read())
# Out:
# 8
# 8
# 8
# 0
# test 1
# test 2
# test 3

# %%
with open('hola.txt','w+') as f:
    print(f.read())

# %%
with open('hola.txt','a') as f:
    print(f.write("test 4 "))
# Out:
# 7

# %%
f=open('new.txt','w+')
f.write("My data ")
f.write("Hello")
f.close()

# %%
f=open('new.txt')
print(f.read())
f.close()
# Out:
# My data Hello

# %% [raw]
# read()

# %%
f=open('new.txt','r')
print(f.read(5))
print(f.read(3))
print(f.read())
f.close()
# Out:
# My da
# ta
# Hello

# %% [markdown]
# readline()

# %%
f=open('hola.txt')
print(f.readline())
print(f.read(5))
print(f.read(3))
print(f.readline())
f.close()
# Out:
# test 1
#
# test
# 2
#
# test 3

# %%
f=open('hola.txt')
print(f.readline(5))
print(f.readlines())
# Out:
# test
# ['1 \n', 'test 2 \n', 'test 3 \n']
