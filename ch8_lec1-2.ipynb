# %%
def div(a,b):
    return a/b
try:
    print(div(5,2))
except:
    print("Exception Occurred")
else:
    print("No Exception")
finally:
    print("Always print")
# Out:
# 2.5
# No Exception
# Always print

# %%
def div(a,b):
    return a/b
try:
    print(div(5,0))
except Exception as e :
    print(e)
else:
    print("No Exception")
finally:
    print("Always print")
# Out:
# division by zero
# Always print

# %%
print(5/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-fad870a50e27> in <module>
# ----> 1 print(5/0)
#
# ZeroDivisionError: division by zero

# %%
try:
    m=5
    f=open("new.txt")
    print(f.read())
    print(m)
    print(5/2)
    l=[1,2,3]
    l[100]
except FileNotFoundError:
    print("File not found")
except NameError:
    print("Variable not defined")
except ZeroDivisionError:
    print("Can't divide by zero")
except Exception as e:
    print(e)
# Out:
# India is my country
# 5
# 2.5
# list index out of range

# %%
try:
    m=5
    f=open("new1.txt")
    print(f.read())
    print(m)
    print(5/2)
    l=[1,2,3]
    l[100]
except FileNotFoundError:
    print("File not found")
except NameError:
    print("Variable not defined")
except ZeroDivisionError:
    print("Can't divide by zero")
except Exception as e:
    print(e)
# Out:
# File not found

# %%
try:
    m=5
    f=open("new.txt")
    print(f.read())
    print(n)
    print(5/2)
    l=[1,2,3]
    l[100]
except FileNotFoundError:
    print("File not found")
except NameError:
    print("Variable not defined")
except ZeroDivisionError:
    print("Can't divide by zero")
except Exception as e:
    print(e)
# Out:
# India is my country
# Variable not defined

# %%
try:
    m=5
    f=open("new.txt")
    print(f.read())
    print(m)
    print(5/0)
    l=[1,2,3]
    l[100]
except FileNotFoundError:
    print("File not found")
except NameError:
    print("Variable not defined")
except ZeroDivisionError:
    print("Can't divide by zero")
except Exception as e:
    print(e)
# Out:
# India is my country
# 5
# Can't divide by zero

# %%
try:
    m=5
    f=open("new.txt")
    print(f.read())
    print(m)
    print(5/2)
    l=[1,2,3]
    l[100]
except FileNotFoundError:
    print("File not found")
except NameError:
    print("Variable not defined")
except ZeroDivisionError:
    print("Can't divide by zero")
except Exception as e:
    print(e)
a=10
b=20
print(a+b)
# Out:
# India is my country
# 5
# 2.5
# list index out of range
# 30

# %%
a=10
b=0
try:
    d=a/c
    print(d)
except (NameError,ZeroDivisionError) as e:
    print(e)
# Out:
# name 'c' is not defined

# %% [markdown]
# Raise an Exception

# %%
def add(a,b):
    return a+b
add("abc","def")
# Out:
# 'abcdef'

# %%
def add(a,b):
    if type(a)==str:
        raise TypeError("a should be int")
    if type(b)==str:
        raise TypeError("b should be int")
    return a+b
add("abc","def")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-949df8f1157e> in <module>
#       5         raise TypeError("b should be int")
#       6     return a+b
# ----> 7 add("abc","def")
#
# <ipython-input-34-949df8f1157e> in add(a, b)
#       1 def add(a,b):
#       2     if type(a)==str:
# ----> 3         raise TypeError("a should be int")
#       4     if type(b)==str:
#       5         raise TypeError("b should be int")
#
# TypeError: a should be int

# %% [markdown]
# Custom Exception

# %%
def add(a,b):
    if type(a)==str:
        raise meet("Perzonalized Error message")
    if type(b)==str:
        raise TypeError("b should be int")
    return a+b
add("abc","def")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c4337ed1a3dc> in <module>
#       5         raise TypeError("b should be int")
#       6     return a+b
# ----> 7 add("abc","def")
#
# <ipython-input-2-c4337ed1a3dc> in add(a, b)
#       1 def add(a,b):
#       2     if type(a)==str:
# ----> 3         raise meet("Perzonalized Error message")
#       4     if type(b)==str:
#       5         raise TypeError("b should be int")
#
# NameError: name 'meet' is not defined

# %%
def money():
    a=int(input("Enter your balance:"))
    b=int(input("Enter money you want to withdraw:"))
    try:
        c=a-b
        if c<2000:
            raise meet("Low amount")
        print(c)
    except meet as e:
        print(e)
money()
# Out:
# Enter your balance:10000
# Enter money you want to withdraw:9000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-10322d039d0c> in money()
#       6         if c<2000:
# ----> 7             raise meet("Low amount")
#       8         print(c)
#
# NameError: name 'meet' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-10322d039d0c> in <module>
#       9     except meet as e:
#      10         print(e)
# ---> 11 money()
#
# <ipython-input-15-10322d039d0c> in money()
#       7             raise meet("Low amount")
#       8         print(c)
# ----> 9     except meet as e:
#      10         print(e)
#      11 money()
#
# NameError: name 'meet' is not defined
